# %%
d = {'admin':'Qwert@123'}
dsq = {'admin':'petname'}
quesList = ['Which is your favourite pet?',
         'What is your childhood name?']

# %%
def checkPasswordStrength(password):
    uc = lc = sc = ac = dc = 0
    strength = 0
    spec = '!@#$%^&*()_+<>?'
    
    for char in password:
        if char.isalpha():         
            ac += 1
            if char.isupper():     uc += 1
            elif char.islower():   lc += 1
        elif char.isdigit():       dc += 1        
        elif char in spec:         sc += 1
    
    if len(password)>8:            strength += 1
    if ac >= 1 and dc >= 1:        strength += 1
    if uc >= 1 and lc >= 1:        strength += 1
    if sc >= 1:                    strength += 1

    if strength >= 3:              return True
    else:                          return False
    
    
#checkPasswordStrength("Qwerty@123")

# %%
def signUp():
    print("\n****Welcome to Coding Thinker SignUp Page****")
    while 1:
        userUp = input('Enter a new Username: ').lower()
        if userUp == '0':
            return 'Failed'
        elif userUp not in d:
            print("""# Length > 8
    # Upper case + Lower Case
    # Special Characters
    # Alphabets and Digits""")
            while(1):
                passUp = input('Enter a strong password: ')
                if passUp == "0":
                    return 'Failed'
                elif checkPasswordStrength(passUp):
                    d.update({userUp:passUp})       # d[userUp] = passUp
                    securityQuestions(userUp)
                    return 'Successful'
                else:
                    print('''Password is weak... Try stronger Password
                    Press 0 to Exit
                    or ''') 
        else:
            print('''Username already exists. Please try another...
                  Press 0 to exit
                  or ''')
#signUp()

# %%
def signIn():
    print("\n****Welcome to Coding Thinker SignIn Page****")
    while 1:
        userIn = input("Enter your existing Username: ").lower()
        if userIn == "0":
            return 'Failed'
        if userIn == '1':
            if signUp(username) == 'Successful':
                continue
            else:
                return 'Failed'
        if userIn in d:
            flag = 3       # status flag
            while flag:
                passIn = input('Enter your Password: ')
                if d[userIn] == passIn:
                    # loginMenu(userIn)
                    return 'Successful'
                else:
                    print('Password Incorrect. Please try again...')
                    fp = input('Forgot Password? Y/N: ').lower()
                    if fp == 'y':
                        forgotPassword("Admin")
                        print('Password Reset...')
                        break
                    else:
                        flag -= 1
        
            if flag == 0: return 'Failed'
        else:
            print("""Username doesn't exist. Please try again...
            Press 0 to Exit
            Press 1 to SignUp with a new Username
            or """)
#signIn()

# %%
def forgotPassword(username):
    flag = 3
    while flag:
        q=input('''press 1 for security question
                or press 2 for otp
                ''')
        if q=='1':
            securityQuestions("Admin")
        elif q=='2':
            otps()
            z=input("enter otp: ")
            if z==otps:
                print("Valid OTP") 
                
            else:
                print("invalide otps")
                flag -= 1
            
        else:
            print("enter valid input")
            flag -= 1

forgotPassword("Admin")
# Out:
# press 1 for security question
#                 or press 2 for otp
#                 2
# SM40cc22500449784cde26e69de7be7652
# enter otp: 5986
# invalide otps

# %%
 def otps():
    import random
    otps = random.randint(1000,9999)
    # Download the helper library from https://www.twilio.com/docs/python/install
    import os
    from twilio.rest import Client
    # Set environment variables for your credentials
    # Read more at http://twil.io/secure
    account_sid = "AC9f18b101e9d4fe954dc7462a494dd63b"
    auth_token = "fb0f631307d39d36fe3638631487351e"
    client = Client(account_sid, auth_token)
    message = client.messages.create(
      body=otps,
      from_="+13613217555",
      to="+919893542266"
    )
    print(message.sid)
# otps()

# %%
def securityQuestions(username):
    print("\n****Please answer the security questions****")
    while True:
        ans1 = input(quesList[0]).lower()
        ans2 = input(quesList[1]).lower()
        sta = input('Are the answers final? Y/N: ').lower()
        if sta == 'y':
            dsq[username] = [ans1, ans2]
            print('Security Questions Saved...')
            return
    
# securityQuestions("Admin")

# %%
while True:
    mode = input("""
    Press 1 for SignUp
    Press 2 for SignIn
    Press 0 to Exit
                     : """)
    if mode == '1':
        print('SignUp', signUp())
        
    elif mode == '2':
        print('SignIn', signIn())
       
        
    elif mode == '0':
        print('Thanks!')
        break
    
    else:
        print('Invalid input. Please try again...')
# Out:
#     Press 1 for SignUp
#     Press 2 for SignIn
#     Press 0 to Exit
#                      : 2
#
# ****Welcome to Coding Thinker SignIn Page****
# Enter your existing Username: Khushi
# Enter your Password: jhvj
# Password Incorrect. Please try again...
# Forgot Password? Y/N: y
# press 1 for security question
#                 or press 2 for otp
#                 or press 3 for 1
#
# ****Please answer the security questions****
# Which is your favourite pet?dog
# What is your childhood name?khus
# Are the answers final? Y/N: y
# Security Questions Saved...
# press 1 for security question
#                 or press 2 for otp
#                 or press 3 for 2
# SM8449be56adedf66697ae34950fe5457a
# enter otp: 2881
# invalide otps
# press 1 for security question
#                 or press 2 for otp
#                 or press 3 for 3
# enter valid input
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 11
#       8     print('SignUp', signUp())
#      10 elif mode == '2':
# ---> 11     print('SignIn', signIn())
#      14 elif mode == '0':
#      15     print('Thanks!')
#
# Cell In[39], line 23, in signIn()
#      21 fp = input('Forgot Password? Y/N: ').lower()
#      22 if fp == 'y':
# ---> 23     forgotPassword("Admin")
#      24     print('Password Reset...')
#      25     break
#
# Cell In[50], line 4, in forgotPassword(username)
#       2 flag = 3
#       3 while flag:
# ----> 4     q=input('''press 1 for security question
#       5             or press 2 for otp
#       6             or press 3 for ''')
#       7     if q=='1':
#       8         securityQuestions("Admin")
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
#    1216     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1217     raise KeyboardInterrupt("Interrupted by user") from None
#    1218 except Exception:
#    1219     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
